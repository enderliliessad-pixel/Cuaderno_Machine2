# %% [markdown]
# ![jupyter](img/logo-itq.png)
#
# # CNN
# ## PAO26-27 - Python 01
#
# ![jupyter](img/logo-py.png)
#
# **Nombre:** *David Ruiz*
# CNN

# %% [markdown]
# # Redes Neuronales y Deep Learning
# ## VC04_V05: Deep Learning y Deep vision

# %%
# SOLO PARA USO EN GOOGLE COLABORATORY
# Para conectar el notebook con la cuenta de gdrive
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)

BASE_FOLDER = '/content/drive/My Drive/Archivo/' # Se debe garantizar que la carpeta docencia compartida se almacena en el directorio raíz de Google Drive. En caso contrario modificar este path
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## **INTRODUCCIÓN A LAS CONVOLUTIONAL NEURAL NETWORKS: MNIST DATASET**

# %% [markdown]
# #### **- Cargando el conjunto de datos**

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
#print(x_train.shape)
#print(y_train.shape)
#print(x_test.shape)
#print(y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %% [markdown]
# #### **- Acondicionando el conjunto de datos**

# %%
# Pre-procesado obligatorio cuando trabajo con redes neuronales
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.backend import expand_dims

x_train, x_te = x_train / 255.0, x_test / 255.0 #Cambio al rango 0-1 -> Disminuyo CC
#¿Que pasa si empleo labels con etiquetas número entero?
print(y_train[0])
#y_train = to_categorical(y_train, num_classes=10) #One-hot encoding para minimizar error
#y_te = to_categorical(y_test, num_classes=10)
x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train, test_size=0.1, random_state=42) # 3 subconjuntos es de vital importancia
#Expandir dimensiones porque en CNN tengo que especificar el número de canales
print(x_tr.shape)
x_tr = expand_dims(x_tr, axis=3)
x_val = expand_dims(x_val, axis=3)
x_te = expand_dims(x_te, axis=3)
print(x_tr.shape)
# Out:
# 5
# (54000, 28, 28)
# (54000, 28, 28, 1)

# %% [markdown]
# #### **- Creando la topología de Red Neuronal (CNN) y entrenándola**

# %%
# Construccion de una red CNN
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
# Red feedforward API secuencial
convnet = Sequential()

# BASE MODEL
convnet.add(layers.Conv2D(32,(3,3),input_shape=(28,28,1),activation='relu', padding='same'))
convnet.add(layers.MaxPooling2D((2,2)))

convnet.add(layers.Conv2D(64,(3,3),activation='relu',padding='same'))
convnet.add(layers.MaxPooling2D((2,2)))

convnet.add(layers.Conv2D(64,(3,3),activation='relu', padding='same'))

#TOP MODEL
convnet.add(layers.Flatten())
convnet.add(layers.Dense(64,activation='relu'))
convnet.add(layers.Dense(10,activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
convnet.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 7, 7, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       200,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 257,162 (1004.54 KB)
#  Trainable params: 257,162 (1004.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
convnet.compile(optimizer='adam',
               loss='sparse_categorical_crossentropy', #If labels are integers
               #loss='categorical_crossentropy', #If labels are one-hot encoded
               metrics=['accuracy'])

# %%
H = convnet.fit(x_tr, y_tr, epochs=5, batch_size=128, validation_data=(x_val, y_val))
# Out:
# Epoch 1/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9385 - loss: 0.2012 - val_accuracy: 0.9782 - val_loss: 0.0656
# Epoch 2/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9833 - loss: 0.0530 - val_accuracy: 0.9878 - val_loss: 0.0412
# Epoch 3/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9887 - loss: 0.0354 - val_accuracy: 0.9878 - val_loss: 0.0399
# Epoch 4/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9917 - loss: 0.0271 - val_accuracy: 0.9895 - val_loss: 0.0359
# Epoch 5/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9933 - loss: 0.0211 - val_accuracy: 0.9853 - val_loss: 0.0473

# %% [markdown]
# #### **- Observando el proceso de entrenamiento para tomar decisiones**

# %%
import matplotlib.pyplot as plt
import numpy as np
# Muestro gráfica de accuracy y losses
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 5), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 5), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 5), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 5), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()

# %% [markdown]
# #### **- Probando el conjunto de datos en el subset de test y evaluando el performance del modelo**

# %%
from sklearn.metrics import classification_report
# Evaluando el modelo de predicción con las imágenes de test
print("[INFO]: Evaluando red neuronal...")
predictions = convnet.predict(x_te, batch_size=128)
#print(y_te[0])
#print(predictions[0])
print(classification_report(y_test, predictions.argmax(axis=1)))
# Out:
# [INFO]: Evaluando red neuronal...
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.98      1.00      0.99      1135
#            2       1.00      0.98      0.99      1032
#            3       0.97      0.99      0.98      1010
#            4       1.00      0.97      0.98       982
#            5       0.97      0.99      0.98       892
#            6       0.99      0.99      0.99       958
#            7       0.99      0.98      0.99      1028
#            8       0.99      0.99      0.99       974
#            9       0.98      0.96      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %% [markdown]
# ## **¿POR QUE CONVOLUTIONAL NEURAL NETWORKS?: CIFAR DATASET**

# %% [markdown]
# #### **- Cargando el conjunto de datos y acondicionándolo**

# %%
# Importando el set de datos CIFAR10
from tensorflow.keras.datasets import cifar10
from sklearn.preprocessing import LabelBinarizer
print("[INFO]: Loading CIFAR-10 data...")
((trainX, trainY), (testX, testY)) = cifar10.load_data()
trainX = trainX.astype("float") / 255.0
testX = testX.astype("float") / 255.0
labelNames = ["Avión", "Automóvil", "Pájaro", "Gato", "Ciervo", "Perro", "Rana", "Caballo", "Barco", "Camión"]
print(trainX.shape)
print(trainY.shape)
# Por si es necesario convertir a one-hot encoding
#lb = LabelBinarizer()
#trainY = lb.fit_transform(trainY)
#testY = lb.transform(testY)
# Out:
# [INFO]: Loading CIFAR-10 data...
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# (50000, 32, 32, 3)
# (50000, 1)

# %%
print(testX.shape)
print(testY.shape)
# Out:
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# #### **- Inspeccionando el conjunto de datos**

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(14,10))
for n in range(1, 29):
    fig.add_subplot(4, 7, n)
    img = trainX[n]
    plt.imshow(img)
    plt.title(labelNames[trainY[n][0]])
    plt.axis('off')

# %% [markdown]
# #### **- Creando la topología de red neuronal y entrenándola: MLP**

# %%
# Imports necesarios
import numpy as np
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt

# Arquitectura de red
# Definimos el modo API Sequential
model = Sequential() #(X)
model.add(Flatten()) #(X)
# Primera capa oculta
model.add(Dense(2048, input_shape=(32*32*3,), activation="relu")) #(X)
#model.add(Dropout(0.5))
# Segunda capa oculta
model.add(Dense(1024, activation="relu")) #(X)
#model.add(Dropout(0.5))
# Tercera capa oculta
model.add(Dense(512, activation="relu")) #(X)
#model.add(Dropout(0.5))
# Cuarta capa oculta
model.add(Dense(128, activation="relu")) #(X)
#model.add(Dropout(0.5))
# Quinta capa oculta
model.add(Dense(32, activation="relu")) #(X)
# Capa de salida
model.add(Dense(10, activation="softmax")) #(X)


# Compilamos el modelo y entrenamos
print("[INFO]: Entrenando red neuronal...")
# Compilamos el modelo
model.compile(loss="sparse_categorical_crossentropy", optimizer=SGD(0.01), metrics=["accuracy"]) # Etiquetas en decimal #(X)
# model.compile(loss="categorical_crossentropy", optimizer=SGD(0.01), metrics=["accuracy"]) # Etiquetas binarias #(X)
# Entrenamos el perceptrón multicapa
H = model.fit(trainX, trainY, validation_split=0.2, epochs=50, batch_size=32) #(X)

# Evaluamos con las muestras de test
print("[INFO]: Evaluando modelo...")
# Efectuamos predicciones
predictions = model.predict(testX, batch_size=32) #(X)
# Obtenemos el report
print(classification_report(testY, predictions.argmax(axis=1), target_names=labelNames)) # Etiquetas en decimal #(X)
# print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=labelNames)) # Etiquetas binarias

# Mostramos gráfica de accuracy y losses
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 50), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 50), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [INFO]: Entrenando red neuronal...
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.3052 - loss: 1.9145 - val_accuracy: 0.3764 - val_loss: 1.7567
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.3951 - loss: 1.6898 - val_accuracy: 0.3868 - val_loss: 1.7158
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4312 - loss: 1.5938 - val_accuracy: 0.4314 - val_loss: 1.5910
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4542 - loss: 1.5263 - val_accuracy: 0.4441 - val_loss: 1.5716
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.4733 - loss: 1.4748 - val_accuracy: 0.4482 - val_loss: 1.5439
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4906 - loss: 1.4244 - val_accuracy: 0.4857 - val_loss: 1.4613
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5070 - loss: 1.3810 - val_accuracy: 0.4749 - val_loss: 1.4836
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5186 - loss: 1.3497 - val_accuracy: 0.4846 - val_loss: 1.4516
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5327 - loss: 1.3071 - val_accuracy: 0.4948 - val_loss: 1.4452
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5454 - loss: 1.2730 - val_accuracy: 0.5070 - val_loss: 1.4085
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5578 - loss: 1.2380 - val_accuracy: 0.5084 - val_loss: 1.4070
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5707 - loss: 1.2023 - val_accuracy: 0.5068 - val_loss: 1.4187
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5842 - loss: 1.1683 - val_accuracy: 0.4983 - val_loss: 1.4467
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5945 - loss: 1.1310 - val_accuracy: 0.5027 - val_loss: 1.4375
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6094 - loss: 1.0980 - val_accuracy: 0.5167 - val_loss: 1.4039
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6205 - loss: 1.0613 - val_accuracy: 0.4954 - val_loss: 1.4835
# Epoch 17/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6321 - loss: 1.0304 - val_accuracy: 0.4806 - val_loss: 1.5448
# Epoch 18/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6464 - loss: 0.9937 - val_accuracy: 0.5110 - val_loss: 1.4357
# Epoch 19/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6592 - loss: 0.9568 - val_accuracy: 0.5185 - val_loss: 1.4552
# Epoch 20/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6690 - loss: 0.9275 - val_accuracy: 0.5125 - val_loss: 1.4785
# Epoch 21/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6824 - loss: 0.8869 - val_accuracy: 0.5250 - val_loss: 1.4645
# Epoch 22/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6960 - loss: 0.8523 - val_accuracy: 0.5367 - val_loss: 1.4358
# Epoch 23/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7088 - loss: 0.8151 - val_accuracy: 0.5026 - val_loss: 1.5740
# Epoch 24/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7198 - loss: 0.7894 - val_accuracy: 0.5422 - val_loss: 1.4745
# Epoch 25/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7346 - loss: 0.7484 - val_accuracy: 0.5228 - val_loss: 1.5788
# Epoch 26/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7473 - loss: 0.7119 - val_accuracy: 0.5055 - val_loss: 1.6971
# Epoch 27/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7571 - loss: 0.6825 - val_accuracy: 0.5290 - val_loss: 1.5532
# Epoch 28/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7677 - loss: 0.6505 - val_accuracy: 0.5348 - val_loss: 1.6047
# Epoch 29/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7854 - loss: 0.6108 - val_accuracy: 0.5217 - val_loss: 1.6555
# Epoch 30/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7944 - loss: 0.5794 - val_accuracy: 0.5320 - val_loss: 1.6922
# Epoch 31/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8067 - loss: 0.5464 - val_accuracy: 0.5185 - val_loss: 1.7935
# Epoch 32/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8167 - loss: 0.5196 - val_accuracy: 0.5180 - val_loss: 1.8850
# Epoch 33/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8256 - loss: 0.4911 - val_accuracy: 0.5234 - val_loss: 1.8424
# Epoch 34/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8353 - loss: 0.4702 - val_accuracy: 0.5113 - val_loss: 2.0280
# Epoch 35/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8442 - loss: 0.4415 - val_accuracy: 0.5211 - val_loss: 1.9981
# Epoch 36/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8542 - loss: 0.4105 - val_accuracy: 0.5350 - val_loss: 1.9200
# Epoch 37/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8617 - loss: 0.3925 - val_accuracy: 0.5044 - val_loss: 2.2809
# Epoch 38/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8694 - loss: 0.3721 - val_accuracy: 0.5139 - val_loss: 2.1872
# Epoch 39/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8739 - loss: 0.3555 - val_accuracy: 0.5307 - val_loss: 2.0709
# Epoch 40/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8834 - loss: 0.3307 - val_accuracy: 0.5277 - val_loss: 2.1486
# Epoch 41/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8947 - loss: 0.3010 - val_accuracy: 0.5286 - val_loss: 2.1829
# Epoch 42/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8979 - loss: 0.2930 - val_accuracy: 0.5333 - val_loss: 2.2423
# Epoch 43/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9021 - loss: 0.2820 - val_accuracy: 0.5244 - val_loss: 2.2658
# Epoch 44/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9017 - loss: 0.2772 - val_accuracy: 0.5301 - val_loss: 2.3394
# Epoch 45/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9122 - loss: 0.2484 - val_accuracy: 0.5332 - val_loss: 2.4140
# Epoch 46/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9175 - loss: 0.2353 - val_accuracy: 0.5190 - val_loss: 2.4788
# Epoch 47/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9232 - loss: 0.2175 - val_accuracy: 0.5325 - val_loss: 2.4956
# Epoch 48/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9262 - loss: 0.2117 - val_accuracy: 0.5341 - val_loss: 2.4838
# Epoch 49/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9311 - loss: 0.1970 - val_accuracy: 0.5241 - val_loss: 2.5432
# Epoch 50/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9280 - loss: 0.2075 - val_accuracy: 0.5311 - val_loss: 2.5366
# [INFO]: Evaluando modelo...
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#               precision    recall  f1-score   support
#
#        Avión       0.59      0.64      0.61      1000
#    Automóvil       0.64      0.65      0.64      1000
#       Pájaro       0.44      0.35      0.39      1000
#         Gato       0.40      0.34      0.37      1000
#       Ciervo       0.39      0.52      0.44      1000
#        Perro       0.44      0.38      0.41      1000
#         Rana       0.60      0.57      0.58      1000
#      Caballo       0.56      0.61      0.58      1000
#        Barco       0.68      0.58      0.63      1000
#       Camión       0.54      0.61      0.58      1000
#
#     accuracy                           0.53     10000
#    macro avg       0.53      0.53      0.52     10000
# weighted avg       0.53      0.53      0.52     10000

# %% [markdown]
# #### **- Creando la topología de red neuronal y entrenándola: CNN**

# %%
# Import the necessary packages
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Conv2D, Activation, Flatten, Dense, Dropout, BatchNormalization, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from google.colab import drive

n_epochs=50
#########################################
###### Definimos la arquitectura ########
#########################################
#BASE MODEL
# Definimos entradas
inputs = Input(shape=(trainX.shape[1], trainX.shape[2], trainX.shape[3]))

# Primer set de capas CONV => RELU => CONV => RELU => POOL
x1 = Conv2D(32, (3, 3), padding="same", activation="relu")(inputs)
x1 = BatchNormalization()(x1)
x1 = Conv2D(32, (3, 3), padding="same", activation="relu")(x1)
x1 = BatchNormalization()(x1)
x1 = MaxPooling2D(pool_size=(2, 2))(x1)
x1 = Dropout(0.25)(x1)

# Segundo set de capas CONV => RELU => CONV => RELU => POOL
x2 = Conv2D(64, (3, 3), padding="same", activation="relu")(x1) #(X)
x2 = BatchNormalization()(x2) #(X)
x2 = Conv2D(64, (3, 3), padding="same", activation="relu")(x2) #(X)
x2 = BatchNormalization()(x2) #(X)
x2 = MaxPooling2D(pool_size=(2, 2))(x2) #(X)
x2 = Dropout(0.25)(x2) #(X)

# Tercer set de capas CONV => RELU => CONV => RELU => POOL
x3 = Conv2D(256, (3, 3), padding="same", activation="relu")(x2) #(X)
x3 = BatchNormalization()(x3) #(X)
x3 = Conv2D(256, (3, 3), padding="same", activation="relu")(x3) #(X)
x3 = BatchNormalization()(x3) #(X)
x3 = MaxPooling2D(pool_size=(2, 2))(x3) #(X)
x3 = Dropout(0.25)(x3) #(X)

# TOP MODEL
# Primer (y único) set de capas FC => RELU
xfc = Flatten()(x3) #(X)
xfc = Dense(512, activation="relu")(xfc) #(X)
xfc = BatchNormalization()(xfc) #(X)
xfc = Dropout(0.5)(xfc) #(X)
# Clasificador softmax
predictions = Dense(10, activation="softmax")(xfc) #(X)

# Unimos las entradas y el modelo mediante la función Model con parámetros inputs y ouputs (Consultar la documentación)
model_cnn = Model(inputs=inputs, outputs=predictions) #(X)

# Compilar el modelo
print("[INFO]: Compilando el modelo...")
model_cnn.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08), metrics=["accuracy"]) #(X)

# Entrenamiento de la red
print("[INFO]: Entrenando la red...")
H = model_cnn.fit(trainX, trainY, validation_split=0.2, batch_size=128, epochs=n_epochs, verbose=1) #(X)

# Almaceno el modelo en Drive
# Montamos la unidad de Drive
drive.mount('/content/drive') #(X)
# Almacenamos el modelo empleando la función mdoel.save de Keras
model_cnn.save(BASE_FOLDER+"deepCNN_CIFAR10.h5") #(X)

# Evaluación del modelo
print("[INFO]: Evaluando el modelo...")
# Efectuamos la predicción (empleamos el mismo valor de batch_size que en training)
predictions = model_cnn.predict(testX, batch_size=128) #(X)
# Sacamos el report para test
print(classification_report(testY, predictions.argmax(axis=1), target_names=labelNames)) #(X)

# Gráficas
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, n_epochs), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, n_epochs), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, n_epochs), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, n_epochs), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# [INFO]: Compilando el modelo...
# [INFO]: Entrenando la red...
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 36s 62ms/step - accuracy: 0.4559 - loss: 1.6459 - val_accuracy: 0.2372 - val_loss: 2.3051
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.6271 - loss: 1.0625 - val_accuracy: 0.6480 - val_loss: 0.9811
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.7012 - loss: 0.8506 - val_accuracy: 0.7135 - val_loss: 0.8109
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.7455 - loss: 0.7278 - val_accuracy: 0.7496 - val_loss: 0.7153
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.7741 - loss: 0.6492 - val_accuracy: 0.7589 - val_loss: 0.7040
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.7962 - loss: 0.5831 - val_accuracy: 0.7832 - val_loss: 0.6250
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.8175 - loss: 0.5208 - val_accuracy: 0.7899 - val_loss: 0.6381
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.8335 - loss: 0.4735 - val_accuracy: 0.7670 - val_loss: 0.7291
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.8510 - loss: 0.4301 - val_accuracy: 0.7855 - val_loss: 0.6626
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.8624 - loss: 0.3871 - val_accuracy: 0.7900 - val_loss: 0.6707
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.8773 - loss: 0.3477 - val_accuracy: 0.8293 - val_loss: 0.5193
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.8890 - loss: 0.3164 - val_accuracy: 0.7931 - val_loss: 0.6534
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9025 - loss: 0.2782 - val_accuracy: 0.8230 - val_loss: 0.5841
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9038 - loss: 0.2695 - val_accuracy: 0.8085 - val_loss: 0.6441
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9156 - loss: 0.2403 - val_accuracy: 0.8217 - val_loss: 0.6256
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9197 - loss: 0.2259 - val_accuracy: 0.8168 - val_loss: 0.6340
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9277 - loss: 0.2054 - val_accuracy: 0.8221 - val_loss: 0.6442
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9330 - loss: 0.1911 - val_accuracy: 0.8408 - val_loss: 0.5713
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9388 - loss: 0.1743 - val_accuracy: 0.8301 - val_loss: 0.6017
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9414 - loss: 0.1688 - val_accuracy: 0.8372 - val_loss: 0.5927
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9421 - loss: 0.1614 - val_accuracy: 0.8423 - val_loss: 0.5854
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9484 - loss: 0.1449 - val_accuracy: 0.8410 - val_loss: 0.5983
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9488 - loss: 0.1444 - val_accuracy: 0.8333 - val_loss: 0.6364
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9530 - loss: 0.1329 - val_accuracy: 0.8414 - val_loss: 0.6326
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9556 - loss: 0.1271 - val_accuracy: 0.8422 - val_loss: 0.6026
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9587 - loss: 0.1173 - val_accuracy: 0.8340 - val_loss: 0.6725
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9569 - loss: 0.1185 - val_accuracy: 0.8137 - val_loss: 0.7959
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9597 - loss: 0.1146 - val_accuracy: 0.8400 - val_loss: 0.6317
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9602 - loss: 0.1113 - val_accuracy: 0.8340 - val_loss: 0.6699
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9606 - loss: 0.1129 - val_accuracy: 0.8391 - val_loss: 0.6701
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9647 - loss: 0.1021 - val_accuracy: 0.8496 - val_loss: 0.6167
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9682 - loss: 0.0907 - val_accuracy: 0.8419 - val_loss: 0.6540
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9678 - loss: 0.0929 - val_accuracy: 0.8413 - val_loss: 0.6559
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9680 - loss: 0.0917 - val_accuracy: 0.8402 - val_loss: 0.6867
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9689 - loss: 0.0909 - val_accuracy: 0.8429 - val_loss: 0.6634
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9686 - loss: 0.0885 - val_accuracy: 0.8414 - val_loss: 0.6539
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9682 - loss: 0.0873 - val_accuracy: 0.8330 - val_loss: 0.7371
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9705 - loss: 0.0854 - val_accuracy: 0.8426 - val_loss: 0.6911
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9713 - loss: 0.0838 - val_accuracy: 0.8497 - val_loss: 0.6457
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.9737 - loss: 0.0764 - val_accuracy: 0.8485 - val_loss: 0.6586
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9742 - loss: 0.0741 - val_accuracy: 0.8371 - val_loss: 0.7028
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9750 - loss: 0.0734 - val_accuracy: 0.8529 - val_loss: 0.6460
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9736 - loss: 0.0750 - val_accuracy: 0.8348 - val_loss: 0.7392
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9761 - loss: 0.0692 - val_accuracy: 0.8382 - val_loss: 0.7310
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9750 - loss: 0.0731 - val_accuracy: 0.8536 - val_loss: 0.6346
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.9745 - loss: 0.0758 - val_accuracy: 0.8548 - val_loss: 0.6395
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9760 - loss: 0.0687 - val_accuracy: 0.8448 - val_loss: 0.7093
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9774 - loss: 0.0651 - val_accuracy: 0.8507 - val_loss: 0.6757
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9776 - loss: 0.0618 - val_accuracy: 0.8511 - val_loss: 0.6816
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9792 - loss: 0.0624 - val_accuracy: 0.8450 - val_loss: 0.6874
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [INFO]: Evaluando el modelo...
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step
#               precision    recall  f1-score   support
#
#        Avión       0.78      0.91      0.84      1000
#    Automóvil       0.93      0.92      0.92      1000
#       Pájaro       0.76      0.81      0.79      1000
#         Gato       0.71      0.71      0.71      1000
#       Ciervo       0.83      0.84      0.83      1000
#        Perro       0.82      0.71      0.76      1000
#         Rana       0.89      0.87      0.88      1000
#      Caballo       0.87      0.88      0.88      1000
#        Barco       0.96      0.87      0.91      1000
#       Camión       0.90      0.91      0.90      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000

# %% [markdown]
# ## **REDUCIENDO OVERFITTING MEDIANTE DATA AUGMENTATION**

# %% [markdown]
# #### **- Acondicionando dataset**

# %%
from sklearn.preprocessing import LabelBinarizer
# Por si es necesario convertir a one-hot encoding
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)
print(trainY.shape)
print(testY.shape)
# Out:
# (50000, 10)
# (10000, 10)

# %% [markdown]
# #### **- Creando un contenedor DataGenerator para el aumento automático de muestras**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15, # grados de rotacion aleatoria
    width_shift_range=0.2, # fraccion del total (1) para mover la imagen
    height_shift_range=0.2, # fraccion del total (1) para mover la imagen
    horizontal_flip=True, # girar las imagenes horizontalmente (eje vertical)
    # shear_range=0, # deslizamiento
    zoom_range=0.2, # rango de zoom
    # fill_mode='nearest', # como rellenar posibles nuevos pixeles
    # channel_shift_range=0.2 # cambios aleatorios en los canales de la imagen
    validation_split=0.2,
)

# %% [markdown]
# #### **- Inspeccionando las muestras generadas sintéticamente**

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
# %matplotlib inline

sample = 13
plt.imshow(image.array_to_img(trainX[sample]))
plt.show()
print('Label = {}'.format(labelNames[trainY[sample].argmax(axis=0)]))

fig, axes = plt.subplots(2,2)
i = 0
for batch in datagen.flow(trainX[sample].reshape((1,32,32,3)),batch_size=1):
    #plt.figure(i)
    axes[i//2,i%2].imshow(image.array_to_img(batch[0]))
    i += 1
    if i == 4:
        break
plt.show()
# Out:
# Label = Pájaro

# %% [markdown]
# #### **- Creando la topología de red neuronal y entrenándola: CNN**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/MyDrive'
# Out:
#  07MIAR_Proyecto_Programacion.ipynb
# '1 parcial_ Imagen Médica.docx'
#  6_UPV2014_ImageProcessing_Introd_Chap6_parte1.docx
#  alejandrogolfe@gmail.com.gdraw
# 'Analítica predictiva'
#  APRENDE
#  Aprendizaje_no_supervisado
# 'Asignaturas de segundo cuatri'
# 'Bloc de notas sin título (4).pdf'
#  box_plot_1.png
# 'CamScanner 01-19-2022 19.46.pdf'
# 'Carpeta sin título'
# 'Carpeta sin título (1)'
# 'Carpeta sin título (2)'
#  CEN-EN13606-COMPOSITION.Cardiology.v1.adl
#  CEN-EN13606-COMPOSITION.Cardiology.v1.map
# 'Centro de investigación'
# 'Clasificación - CASEIB_2018.pptx'
# 'Colab Notebooks'
# 'Compact Advanced C1. Students Book with Answers (May Peter.) (z-lib.org).pdf'
#  Compact_Advanced___Classroom_Audio.zip
#  comprobante.pdf
# 'Confirmación de asistencia al evento.gform'
# 'Confirmación de asistencia al evento (respuestas).gsheet'
#  contadorPicos.m
#  Conv+BatchNorm.pptx
# 'Copia de crowsourcing_method.gdraw'
# 'Copia de KD_resolution_Rocío.gdraw'
#  correccion_practicaPNG.PNG
#  Curso_deepLearning
#  curso_deep_learning_mod
#  Curso_DL_CFP
#  dataset
#  data.zip
#  Datos_práctica_final
#  DCGAN_FashionMNIST_Práctica_RUBEN_CASAS_POLIDORI.ipynb
#  Deep_Learning_Aplicado_Al_An_l_2023_06_29.xlsx
# 'Definitive - Galahad (V+G+R).pptx'
# 'Diagrama sin título.drawio'
# 'Dibujo sin título (100).gdraw'
# 'Dibujo sin título (101).gdraw'
# 'Dibujo sin título (102).gdraw'
# 'Dibujo sin título (103).gdraw'
# 'Dibujo sin título (104).gdraw'
# 'Dibujo sin título (105).gdraw'
# 'Dibujo sin título (106).gdraw'
# 'Dibujo sin título (107).gdraw'
# 'Dibujo sin título (108).gdraw'
# 'Dibujo sin título (109).gdraw'
# 'Dibujo sin título (10).gdraw'
# 'Dibujo sin título (110).gdraw'
# 'Dibujo sin título (111).gdraw'
# 'Dibujo sin título (112).gdraw'
# 'Dibujo sin título (113).gdraw'
# 'Dibujo sin título (114).gdraw'
# 'Dibujo sin título (115).gdraw'
# 'Dibujo sin título (116).gdraw'
# 'Dibujo sin título (117).gdraw'
# 'Dibujo sin título (118).gdraw'
# 'Dibujo sin título (119).gdraw'
# 'Dibujo sin título (11).gdraw'
# 'Dibujo sin título (120).gdraw'
# 'Dibujo sin título (121).gdraw'
# 'Dibujo sin título (122).gdraw'
# 'Dibujo sin título (123).gdraw'
# 'Dibujo sin título (124).gdraw'
# 'Dibujo sin título (125).gdraw'
# 'Dibujo sin título (126).gdraw'
# 'Dibujo sin título (127).gdraw'
# 'Dibujo sin título (128).gdraw'
# 'Dibujo sin título (129).gdraw'
# 'Dibujo sin título (12).gdraw'
# 'Dibujo sin título (130).gdraw'
# 'Dibujo sin título (131).gdraw'
# 'Dibujo sin título (132).gdraw'
# 'Dibujo sin título (133).gdraw'
# 'Dibujo sin título (134).gdraw'
# 'Dibujo sin título (135).gdraw'
# 'Dibujo sin título (136).gdraw'
# 'Dibujo sin título (137).gdraw'
# 'Dibujo sin título (138).gdraw'
# 'Dibujo sin título (139).gdraw'
# 'Dibujo sin título (13).gdraw'
# 'Dibujo sin título (140).gdraw'
# 'Dibujo sin título (141).gdraw'
# 'Dibujo sin título (142).gdraw'
# 'Dibujo sin título (143).gdraw'
# 'Dibujo sin título (144).gdraw'
# 'Dibujo sin título (145).gdraw'
# 'Dibujo sin título (146).gdraw'
# 'Dibujo sin título (147).gdraw'
# 'Dibujo sin título (148).gdraw'
# 'Dibujo sin título (14).gdraw'
# 'Dibujo sin título (15).gdraw'
# 'Dibujo sin título (16).gdraw'
# 'Dibujo sin título (17).gdraw'
# 'Dibujo sin título (18).gdraw'
# 'Dibujo sin título (19).gdraw'
# 'Dibujo sin título (1).gdraw'
# 'Dibujo sin título (20).gdraw'
# 'Dibujo sin título (21).gdraw'
# 'Dibujo sin título (22).gdraw'
# 'Dibujo sin título (23).gdraw'
# 'Dibujo sin título (24).gdraw'
# 'Dibujo sin título (25).gdraw'
# 'Dibujo sin título (26).gdraw'
# 'Dibujo sin título (27).gdraw'
# 'Dibujo sin título (28).gdraw'
# 'Dibujo sin título (29).gdraw'
# 'Dibujo sin título (2).gdraw'
# 'Dibujo sin título (30).gdraw'
# 'Dibujo sin título (31).gdraw'
# 'Dibujo sin título (32).gdraw'
# 'Dibujo sin título (33).gdraw'
# 'Dibujo sin título (34).gdraw'
# 'Dibujo sin título (35).gdraw'
# 'Dibujo sin título (36).gdraw'
# 'Dibujo sin título (37).gdraw'
# 'Dibujo sin título (38).gdraw'
# 'Dibujo sin título (39).gdraw'
# 'Dibujo sin título (3).gdraw'
# 'Dibujo sin título (40).gdraw'
# 'Dibujo sin título (41).gdraw'
# 'Dibujo sin título (42).gdraw'
# 'Dibujo sin título (43).gdraw'
# 'Dibujo sin título (44).gdraw'
# 'Dibujo sin título (45).gdraw'
# 'Dibujo sin título (46).gdraw'
# 'Dibujo sin título (47).gdraw'
# 'Dibujo sin título (48).gdraw'
# 'Dibujo sin título (49).gdraw'
# 'Dibujo sin título (4).gdraw'
# 'Dibujo sin título (50).gdraw'
# 'Dibujo sin título (51).gdraw'
# 'Dibujo sin título (52).gdraw'
# 'Dibujo sin título (53).gdraw'
# 'Dibujo sin título (54).gdraw'
# 'Dibujo sin título (55).gdraw'
# 'Dibujo sin título (56).gdraw'
# 'Dibujo sin título (57).gdraw'
# 'Dibujo sin título (58).gdraw'
# 'Dibujo sin título (59).gdraw'
# 'Dibujo sin título (5).gdraw'
# 'Dibujo sin título (60).gdraw'
# 'Dibujo sin título (61).gdraw'
# 'Dibujo sin título (62).gdraw'
# 'Dibujo sin título (63).gdraw'
# 'Dibujo sin título (64).gdraw'
# 'Dibujo sin título (65).gdraw'
# 'Dibujo sin título (66).gdraw'
# 'Dibujo sin título (67).gdraw'
# 'Dibujo sin título (68).gdraw'
# 'Dibujo sin título (69).gdraw'
# 'Dibujo sin título (6).gdraw'
# 'Dibujo sin título (70).gdraw'
# 'Dibujo sin título (71).gdraw'
# 'Dibujo sin título (72).gdraw'
# 'Dibujo sin título (73).gdraw'
# 'Dibujo sin título (74).gdraw'
# 'Dibujo sin título (75).gdraw'
# 'Dibujo sin título (76).gdraw'
# 'Dibujo sin título (77).gdraw'
# 'Dibujo sin título (78).gdraw'
# 'Dibujo sin título (79).gdraw'
# 'Dibujo sin título (7).gdraw'
# 'Dibujo sin título (80).gdraw'
# 'Dibujo sin título (81).gdraw'
# 'Dibujo sin título (82).gdraw'
# 'Dibujo sin título (83).gdraw'
# 'Dibujo sin título (84).gdraw'
# 'Dibujo sin título (85).gdraw'
# 'Dibujo sin título (86).gdraw'
# 'Dibujo sin título (87).gdraw'
# 'Dibujo sin título (88).gdraw'
# 'Dibujo sin título (89).gdraw'
# 'Dibujo sin título (8).gdraw'
# 'Dibujo sin título (90).gdraw'
# 'Dibujo sin título (91).gdraw'
# 'Dibujo sin título (92).gdraw'
# 'Dibujo sin título (93).gdraw'
# 'Dibujo sin título (94).gdraw'
# 'Dibujo sin título (95).gdraw'
# 'Dibujo sin título (96).gdraw'
# 'Dibujo sin título (97).gdraw'
# 'Dibujo sin título (98).gdraw'
# 'Dibujo sin título (99).gdraw'
# 'Dibujo sin título (9).gdraw'
# 'Dibujo sin título.gdraw'
#  DIPSY_UPV_UC3M
#  DL_VIU
# 'Documento sin título (1).gdoc'
# 'Documento sin título (2).gdoc'
# 'Documento sin título.gdoc'
#  elated_clinical_information_model_ID.xquery
#  electronic_poster_delAmor_Rocio.gdoc
#  electronic_poster_delAmor_Rocio.jpg
#  enunciado_prácticaPNG.PNG
# 'Esquema ruido.pdf'
# 'Estado de arte.gdoc'
#  Europass
#  EUSIPCO_2019.pptx
#  expediente_2018.pdf
# 'Expediente Academico Rocio (1).pdf'
# 'Expediente Academico Rocio.pdf'
# 'Explora aplicación psicólogos.gdoc'
#  extract_CI.m.gdoc
#  figura11.jpg
#  figura12.jpg
#  figura5.jpg
#  figura6.jpg
#  final_boundaries.zip
#  final_data.npy
# 'Formulario sin título (1).gform'
# 'Formulario sin título.gform'
#  fotos
#  G42P6.pdf
#  G43P7.pdf
# 'GANs - 2. Mi primera DCGAN - MNIST.ipynb'
#  GANs_condicionales_FashionMNIST_Práctica_RUBEN_CASAS_POLIDORI.ipynb
#  Grabación_clase_dudas
#  helices_adn.jpg
# 'How to get started with Drive.pdf'
# 'Imágenes Capitulo IA.gdoc'
#  imagenes_tfg
#  images.npy
# 'INNOSALUD - Contenidos Informe de mercado y Modelo de Negocio.docx'
# 'INNOSALUD - Plantilla resumen ejecutivo_PSYTRACK.docx'
#  Keep_coding
# 'Lecture_AI in healthcare_VFinal_2023 (1).pptx'
# 'Lecture_AI in healthcare_VFinal_2023.pptx'
#  Listas_TDC
#  Methodology.gdoc
# 'MN_2 y financiacion.docx'
# 'Modelos de negocio.docx'
#  modelos_jose.zip
# 'Multi_Resolution_Spitzoid_Images_final_V (3).pdf'
#  Nanotecnología
# 'Nombre del proyecto: Deep Learning for Health.gdoc'
#  normalized-record-1.xml
# 'NuevoDocumento 2017-02-27.pdf'
# 'NuevoDocumento 2017-10-25.pdf'
#  Nuevo_speckle.zip
#  overview_labeling_uncertainty_tesis.gdraw
#  P1_Fordward_y_Backpropagation__Evaluando_el_perceptron_con_funciones_logicas.json
# 'P4. CNNs con Keras para la clasificación de imágenes.ipynb'
#  pablomesegueresbri@gmail.com.gdoc
#  paper_Final_modificado.docx
#  paper_pel.gdraw
#  Parte_lucia_Rocio.docx
#  ParteRocio_audio.docx
# 'Parte Rocío.docx'
#  PET.pdf
# 'PHRI AI 17.05 - Gastro V1.docx'
# 'Planning Bristol.gdoc'
#  PMI.png
#  POWER_TFG_Rocio.pptx
#  practica%2B1+de+ingeniera.xlsx
# 'Practica3.Biomat (3) modificada_ultimisima.docx'
# 'Practica3.Biomat (3) modificada_ultimisima.pdf'
# 'Practica3.Biomat IMPRIMIR.pdf'
# 'Práctica de señales'
# 'Practica Proyectos y fabricación..gdoc'
# 'Prácticas la Fe.gdoc'
# 'Prácticas SIT II'
#  presentacionRocio.docx
# 'Presentación TFM Gabri (1).pptx'
#  primeraSimulacion.mat
# 'Proyectos y Fabricación GIB-1819-fondo blanco.pdf'
#  Proyecto_UPV_UC3M
#  prueba_dataset
# 'qci-qdcn-ame-11 nov. 2020.gjam'
#  Recibo_keep_coding_Rocio_mod.pdf
#  Recibo_keep_coding_Rocio_practicas.pdf
#  repo.PNG
#  resolución_práctica.PNG
#  Revisiones.gdoc
#  Rocío
#  ROI.gdoc
# 'ROI & manifold learning.gdoc'
# 'Season 1.gsheet'
#  Segmentacion
# 'SEQUOIA_VIV_221013_B_WP7_UPV - copia.pptx'
# 'SER RICOS??? JEJEJ.gdoc'
#  Sesiones
# 'SIC_EXPE (2) (1).pdf'
# 'SIC_EXPE (2).pdf'
#  SIT1_Test1_A_2017_solucion.doc
#  SPECT.pdf
#  talk3_1500.pptx
#  Tarea1
#  Tarea2
#  tarea4.docx
# 'Tema 10.3 y 10.4.docx'
# 'Tema 1.docx'
#  Tema_1_Introduccion.pdf
# 'Tema 2 - Fundamentos de analitica predictiva.pdf'
#  Tema_3_AED.pdf
#  Tema_4_Agrupamiento.pdf
#  Tema_5_Clasificacion_Prediccion_final.pdf
# 'Tenicas de imagen. Segundo cuatri'
# 'Tesis. Titanio_tantalio.pdf'
#  TFM_particion_datos.gdraw
# 'Thesis_RAA - Talk_final_v2 (1).pptx'
# 'Thesis_RAA - Talk_final_v2.pptx'
#  transcriptional_view.pdf
#  TurbO
# 'ultima practica'
#  Untitled0.ipynb
#  Untitled1.ipynb
# 'Untitled Diagram (1).drawio'
# 'Untitled Diagram (1).pdf'
# 'Untitled Diagram (2).drawio'
# 'Untitled Diagram (2).pdf'
# 'Untitled Diagram (3).drawio'
# 'Untitled Diagram.drawio'
# 'Untitled Diagram.pdf'
# 'User manual.pdf'
#  Valery_Naranjo.jpg
# 'Viaje Galicia.gdoc'
# 'Wind turbine blades undergo high operational loads, experience variable environmental conditions, and are susceptible to failure due to defects, fatigue, and weather-induced damage [1].gdoc'

# %%
# Import the necessary packages
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Conv2D, Activation, Flatten, Dense, Dropout, BatchNormalization, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD, Adam
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from google.colab import drive

#########################################
###### Definimos la arquitectura ########
#########################################
# Definimos entradas
inp = Input(shape=(trainX.shape[1], trainX.shape[2], trainX.shape[3]))

# Primer set de capas CONV => RELU => CONV => RELU => POOL
x1 = Conv2D(32, (3, 3), padding="same", activation="relu")(inp)
x1 = BatchNormalization()(x1)
x1 = Conv2D(32, (3, 3), padding="same", activation="relu")(x1)
x1 = BatchNormalization()(x1)
x1 = MaxPooling2D(pool_size=(2, 2))(x1)
x1 = Dropout(0.25)(x1)

# Segundo set de capas CONV => RELU => CONV => RELU => POOL
x2 = Conv2D(64, (3, 3), padding="same", activation="relu")(x1)
x2 = BatchNormalization()(x2)
x2 = Conv2D(64, (3, 3), padding="same", activation="relu")(x2)
x2 = BatchNormalization()(x2)
x2 = MaxPooling2D(pool_size=(2, 2))(x2)
x2 = Dropout(0.25)(x2)

# Segundo set de capas CONV => RELU => CONV => RELU => POOL
x2 = Conv2D(256, (3, 3), padding="same", activation="relu")(x2)
x2 = BatchNormalization()(x2)
x2 = Conv2D(256, (3, 3), padding="same", activation="relu")(x2)
x2 = BatchNormalization()(x2)
x2 = MaxPooling2D(pool_size=(2, 2))(x2)
x2 = Dropout(0.25)(x2)

# Primer (y único) set de capas FC => RELU
xfc = Flatten()(x2)
xfc = Dense(512, activation="relu")(xfc)
xfc = BatchNormalization()(xfc)
xfc = Dropout(0.5)(xfc)
# Clasificador softmax
predictions = Dense(10, activation="softmax")(xfc)

# Unimos las entradas y el modelo mediante la función Model con parámetros inputs y ouputs (Consultar la documentación)
model_aug = Model(inputs=inp, outputs=predictions)

# Compilar el modelo
print("[INFO]: Compilando el modelo...")
model_aug.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08), metrics=["accuracy"])

# Entrenamiento de la red
print("[INFO]: Entrenando la red...")
H_aug = model_aug.fit(datagen.flow(trainX, trainY, batch_size=128, subset="training"),
                                steps_per_epoch = len(trainX)// 128, epochs=50, validation_data=datagen.flow(trainX, trainY, batch_size=8, subset="validation"))
# Almaceno el modelo en Drive
# Montamos la unidad de Drive
drive.mount('/content/drive')
# Almacenamos el modelo empleando la función mdoel.save de Keras
model_aug.save(BASE_FOLDER+"deepCNN_CIFAR10_aug.h5")

# Evaluación del modelo
print("[INFO]: Evaluando el modelo...")
# Efectuamos la predicción (empleamos el mismo valor de batch_size que en training)
predictions = model_aug.predict(testX, batch_size=128)
# Sacamos el report para test
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=labelNames))

# Gráficas
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H_aug.history["loss"], label="train_loss")
plt.plot(np.arange(0, 50), H_aug.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), H_aug.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 50), H_aug.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# [INFO]: Compilando el modelo...
# [INFO]: Entrenando la red...
# Epoch 1/50
# 313/390 ━━━━━━━━━━━━━━━━━━━━ 9s 118ms/step - accuracy: 0.2809 - loss: 2.3902
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 66s 123ms/step - accuracy: 0.3442 - loss: 2.0157 - val_accuracy: 0.1281 - val_loss: 3.9415
# Epoch 2/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 102ms/step - accuracy: 0.4712 - loss: 1.5230 - val_accuracy: 0.4499 - val_loss: 1.5678
# Epoch 3/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 102ms/step - accuracy: 0.5385 - loss: 1.2973 - val_accuracy: 0.4926 - val_loss: 1.5147
# Epoch 4/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.5966 - loss: 1.1370 - val_accuracy: 0.5899 - val_loss: 1.2013
# Epoch 5/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 102ms/step - accuracy: 0.6326 - loss: 1.0382 - val_accuracy: 0.6137 - val_loss: 1.1173
# Epoch 6/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.6585 - loss: 0.9670 - val_accuracy: 0.6410 - val_loss: 1.0507
# Epoch 7/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 50s 127ms/step - accuracy: 0.6814 - loss: 0.9086 - val_accuracy: 0.6036 - val_loss: 1.1971
# Epoch 8/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.6956 - loss: 0.8669 - val_accuracy: 0.7045 - val_loss: 0.8450
# Epoch 9/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 104ms/step - accuracy: 0.7110 - loss: 0.8231 - val_accuracy: 0.7272 - val_loss: 0.7865
# Epoch 10/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.7260 - loss: 0.7903 - val_accuracy: 0.7232 - val_loss: 0.8053
# Epoch 11/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.7330 - loss: 0.7642 - val_accuracy: 0.6740 - val_loss: 0.9977
# Epoch 12/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.7434 - loss: 0.7365 - val_accuracy: 0.7314 - val_loss: 0.7886
# Epoch 13/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.7553 - loss: 0.7093 - val_accuracy: 0.7755 - val_loss: 0.6553
# Epoch 14/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 39s 101ms/step - accuracy: 0.7610 - loss: 0.6879 - val_accuracy: 0.7764 - val_loss: 0.6641
# Epoch 15/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 102ms/step - accuracy: 0.7658 - loss: 0.6750 - val_accuracy: 0.7717 - val_loss: 0.6553
# Epoch 16/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 39s 101ms/step - accuracy: 0.7749 - loss: 0.6486 - val_accuracy: 0.6436 - val_loss: 1.1128
# Epoch 17/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 102ms/step - accuracy: 0.7794 - loss: 0.6399 - val_accuracy: 0.7944 - val_loss: 0.5970
# Epoch 18/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.7813 - loss: 0.6238 - val_accuracy: 0.7982 - val_loss: 0.5859
# Epoch 19/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.7893 - loss: 0.6158 - val_accuracy: 0.7622 - val_loss: 0.7203
# Epoch 20/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.7937 - loss: 0.5981 - val_accuracy: 0.7985 - val_loss: 0.5911
# Epoch 21/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.7981 - loss: 0.5859 - val_accuracy: 0.7919 - val_loss: 0.6237
# Epoch 22/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.8030 - loss: 0.5702 - val_accuracy: 0.7971 - val_loss: 0.6071
# Epoch 23/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.8049 - loss: 0.5666 - val_accuracy: 0.7450 - val_loss: 0.7698
# Epoch 24/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 102ms/step - accuracy: 0.8087 - loss: 0.5510 - val_accuracy: 0.7922 - val_loss: 0.6245
# Epoch 25/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.8088 - loss: 0.5503 - val_accuracy: 0.8138 - val_loss: 0.5474
# Epoch 26/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.8124 - loss: 0.5403 - val_accuracy: 0.8198 - val_loss: 0.5160
# Epoch 27/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.8156 - loss: 0.5311 - val_accuracy: 0.7926 - val_loss: 0.6102
# Epoch 28/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.8194 - loss: 0.5220 - val_accuracy: 0.8131 - val_loss: 0.5425
# Epoch 29/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.8224 - loss: 0.5159 - val_accuracy: 0.8233 - val_loss: 0.5172
# Epoch 30/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.8249 - loss: 0.5075 - val_accuracy: 0.8004 - val_loss: 0.5903
# Epoch 31/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.8275 - loss: 0.5000 - val_accuracy: 0.8179 - val_loss: 0.5406
# Epoch 32/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 41s 105ms/step - accuracy: 0.8263 - loss: 0.4980 - val_accuracy: 0.8313 - val_loss: 0.5051
# Epoch 33/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 102ms/step - accuracy: 0.8306 - loss: 0.4897 - val_accuracy: 0.8222 - val_loss: 0.5180
# Epoch 34/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 102ms/step - accuracy: 0.8302 - loss: 0.4859 - val_accuracy: 0.8191 - val_loss: 0.5423
# Epoch 35/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.8333 - loss: 0.4811 - val_accuracy: 0.8382 - val_loss: 0.4765
# Epoch 36/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.8352 - loss: 0.4747 - val_accuracy: 0.8341 - val_loss: 0.4841
# Epoch 37/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.8343 - loss: 0.4732 - val_accuracy: 0.8116 - val_loss: 0.5694
# Epoch 38/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.8382 - loss: 0.4652 - val_accuracy: 0.8293 - val_loss: 0.5133
# Epoch 39/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 41s 103ms/step - accuracy: 0.8433 - loss: 0.4573 - val_accuracy: 0.8431 - val_loss: 0.4630
# Epoch 40/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 41s 102ms/step - accuracy: 0.8432 - loss: 0.4532 - val_accuracy: 0.8394 - val_loss: 0.4708
# Epoch 41/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 39s 101ms/step - accuracy: 0.8461 - loss: 0.4492 - val_accuracy: 0.8402 - val_loss: 0.4843
# Epoch 42/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 42s 103ms/step - accuracy: 0.8450 - loss: 0.4455 - val_accuracy: 0.8327 - val_loss: 0.4980
# Epoch 43/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.8447 - loss: 0.4481 - val_accuracy: 0.8418 - val_loss: 0.4641
# Epoch 44/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.8519 - loss: 0.4315 - val_accuracy: 0.8435 - val_loss: 0.4512
# Epoch 45/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 102ms/step - accuracy: 0.8482 - loss: 0.4325 - val_accuracy: 0.8402 - val_loss: 0.4658
# Epoch 46/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.8518 - loss: 0.4296 - val_accuracy: 0.8430 - val_loss: 0.4565
# Epoch 47/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 102ms/step - accuracy: 0.8529 - loss: 0.4274 - val_accuracy: 0.8452 - val_loss: 0.4714
# Epoch 48/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.8561 - loss: 0.4195 - val_accuracy: 0.8473 - val_loss: 0.4559
# Epoch 49/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.8565 - loss: 0.4143 - val_accuracy: 0.8503 - val_loss: 0.4390
# Epoch 50/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 40s 104ms/step - accuracy: 0.8553 - loss: 0.4137 - val_accuracy: 0.8335 - val_loss: 0.4914
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [INFO]: Evaluando el modelo...
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step
#               precision    recall  f1-score   support
#
#        Avión       0.92      0.81      0.86      1000
#    Automóvil       0.95      0.93      0.94      1000
#       Pájaro       0.87      0.78      0.82      1000
#         Gato       0.81      0.65      0.72      1000
#       Ciervo       0.82      0.87      0.85      1000
#        Perro       0.88      0.70      0.78      1000
#         Rana       0.67      0.96      0.79      1000
#      Caballo       0.90      0.91      0.91      1000
#        Barco       0.92      0.92      0.92      1000
#       Camión       0.83      0.97      0.89      1000
#
#     accuracy                           0.85     10000
#    macro avg       0.86      0.85      0.85     10000
# weighted avg       0.86      0.85      0.85     10000

# %% [markdown]
# **EJERCICIO PROPUESTO:** Modificar la ejecución con Data Augmentation para que sea directamente comparable a la ejecución por defecto. Para ello, el validation data debe ser correcto. Pista: Llevar a cabo el validation split cuando se instancia el objeto ImageDataGenerator. El método flow también se verá afectado (leer documentación).

# %% [markdown]
# ## **TRABAJANDO CON REDES PRE-ENTRENADAS: TRANSFER LEARNING & FINE-TUNING**

# %% [markdown]
# #### **- Cargando el conjunto de datos y acondicionándolo como en la VGG**

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications import imagenet_utils
from sklearn.preprocessing import LabelBinarizer

# Importando y normalizando el set de datos CIFAR10
print("[INFO]: Loading CIFAR-10 data...")
((trainX, trainY), (testX, testY)) = cifar10.load_data()
labelNames = ["Avión", "Automóvil", "Pájaro", "Gato", "Ciervo", "Perro", "Rana", "Caballo", "Barco", "Camión"]

#One-hot encoding
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

# IMPORTANTE: Se normalizan los datos como se normalizaron en el entrenamiento con ImageNet!!
trainX = imagenet_utils.preprocess_input(trainX)
testX = imagenet_utils.preprocess_input(testX)

print(trainX.shape)
#print(trainY.shape)
# Out:
# [INFO]: Loading CIFAR-10 data...
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# (50000, 32, 32, 3)

# %% [markdown]
# #### **- Cargando la topología de CNN (base model)**

# %%
#keras incluye varias arquitecturas
# VGG16, VGG19, ResNet50, Xception, InceptionV3, InceptionResNetV2, MobileNetV2, DenseNet, RasNet
# documentacion https://keras.io/applications/
# Visual Geometry Group 16 / 19 (numero de layers)
# 1 y 2 en la competicion ImageNet 2014
# Kernels pequeños de 3x3

from tensorflow.keras.applications import VGG16

base_model = VGG16(weights='imagenet',
                 include_top=False, # No incluir el top model, i.e. la parte densa destinada a la clasificación (fully connected layers)
                 input_shape=(32,32,3))
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 4, 4, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 1, 1, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### **- Creando el top model y congelando TODAS las capas convolucionales (TRANSFER LEARNING)**

# %%
# conectarlo a nueva parte densa
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

base_model.trainable = False # Evitar que los pesos se modifiquen en la parte convolucional -> TRANSFER LEARNING
pre_trained_model = Sequential()
pre_trained_model.add(base_model)
pre_trained_model.add(layers.Flatten())
pre_trained_model.add(layers.Dense(256, activation='relu', name="densa_1"))
pre_trained_model.add(layers.Dense(10, activation='softmax'))

pre_trained_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 1, 1, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densa_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,848,586 (56.64 MB)
#  Trainable params: 133,898 (523.04 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# #### **- Entrenando la solución**

# %%
# Import the necessary packages
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Conv2D, Activation, Flatten, Dense, Dropout, BatchNormalization, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD, Adam
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from google.colab import drive

# Compilar el modelo
print("[INFO]: Compilando el modelo...")
pre_trained_model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08), metrics=["accuracy"])

# Entrenamiento de la red
print("[INFO]: Entrenando la red...")
H_pre = pre_trained_model.fit(trainX, trainY, batch_size=128, epochs=20, validation_split=0.2)
# Almaceno el modelo en Drive
# Montamos la unidad de Drive
drive.mount('/content/drive')
BASE_FOLDER = "/content/drive/MyDrive/"
# Almacenamos el modelo empleando la función mdoel.save de Keras
pre_trained_model.save(BASE_FOLDER+"deepCNN_CIFAR10_pretrained.h5") #(X)

# Evaluación del modelo
print("[INFO]: Evaluando el modelo...")
# Efectuamos la predicción (empleamos el mismo valor de batch_size que en training)
predictions = pre_trained_model.predict(testX, batch_size=128)
# Sacamos el report para test
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=labelNames))

# Gráficas
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 20), H_pre.history["loss"], label="train_loss")
plt.plot(np.arange(0, 20), H_pre.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 20), H_pre.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 20), H_pre.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# [INFO]: Compilando el modelo...
# [INFO]: Entrenando la red...
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - accuracy: 0.9706 - loss: 0.1003 - val_accuracy: 0.6246 - val_loss: 2.2640
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.9784 - loss: 0.0800 - val_accuracy: 0.6256 - val_loss: 2.4026
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.9809 - loss: 0.0717 - val_accuracy: 0.6253 - val_loss: 2.4644
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.9852 - loss: 0.0594 - val_accuracy: 0.6289 - val_loss: 2.5026
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.9828 - loss: 0.0639 - val_accuracy: 0.6246 - val_loss: 2.6009
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.9812 - loss: 0.0663 - val_accuracy: 0.6272 - val_loss: 2.6463
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.9824 - loss: 0.0610 - val_accuracy: 0.6280 - val_loss: 2.7707
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.9870 - loss: 0.0509 - val_accuracy: 0.6279 - val_loss: 2.7956
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.9887 - loss: 0.0431 - val_accuracy: 0.6305 - val_loss: 2.8511
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.9930 - loss: 0.0319 - val_accuracy: 0.6279 - val_loss: 2.8797
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.9941 - loss: 0.0305 - val_accuracy: 0.6263 - val_loss: 2.9381
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.9903 - loss: 0.0379 - val_accuracy: 0.6228 - val_loss: 3.0920
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.9814 - loss: 0.0604 - val_accuracy: 0.6233 - val_loss: 3.1167
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.9756 - loss: 0.0732 - val_accuracy: 0.6187 - val_loss: 3.1207
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.9855 - loss: 0.0481 - val_accuracy: 0.6242 - val_loss: 3.1752
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.9929 - loss: 0.0281 - val_accuracy: 0.6214 - val_loss: 3.2339
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.9966 - loss: 0.0188 - val_accuracy: 0.6325 - val_loss: 3.2022
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.9986 - loss: 0.0115 - val_accuracy: 0.6327 - val_loss: 3.2357
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.9997 - loss: 0.0054 - val_accuracy: 0.6335 - val_loss: 3.2383
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.6358 - val_loss: 3.2707
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [INFO]: Evaluando el modelo...
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step
#               precision    recall  f1-score   support
#
#        Avión       0.70      0.70      0.70      1000
#    Automóvil       0.72      0.70      0.71      1000
#       Pájaro       0.55      0.56      0.56      1000
#         Gato       0.49      0.45      0.47      1000
#       Ciervo       0.58      0.56      0.57      1000
#        Perro       0.56      0.57      0.57      1000
#         Rana       0.65      0.70      0.68      1000
#      Caballo       0.68      0.65      0.66      1000
#        Barco       0.75      0.76      0.75      1000
#       Camión       0.66      0.71      0.68      1000
#
#     accuracy                           0.63     10000
#    macro avg       0.63      0.63      0.63     10000
# weighted avg       0.63      0.63      0.63     10000

# %% [markdown]
# #### **- Creando el top model y descongelando bloques convolucionales (FINE TUNING)**

# %%
# Imports que vamos a necesitar
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.applications import VGG16, imagenet_utils
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dropout, Flatten, GlobalMaxPooling2D, Dense
from tensorflow.keras import Model
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import numpy as np
from sklearn.preprocessing import LabelBinarizer

#Cargamos el dataset CIFAR10
(trainX, trainY), (testX, testY) = cifar10.load_data()

# Normalizamos las entradas de idéntica forma a como lo hicieron para entrenar la VGG16 en imageNet
trainX = imagenet_utils.preprocess_input(trainX)
testX = imagenet_utils.preprocess_input(testX)

# Definimos dimensiones de nuestros datos de entrada y lista con las categorias de las clases
input_shape = (32, 32, 3)
labelNames = ["Avión", "Automóvil", "Pájaro", "Gato", "Ciervo", "Perro", "Rana", "Caballo", "Barco", "Camión"]

# En caso de inestabilidades numéricas pasar datos a one-hot encoding
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

# Importamos VGG16 con pesos de imagenet y sin top_model especificando tamaño de entrada de datos
base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
# Mostramos la arquitectura
base_model.summary()

# Congelamos las capas de los 4 primeros bloques convolucionales, el quinto se re-entrena
# En base_model.layers.name tenemos la información del nombre de la capa
for layer in base_model.layers:
  if layer.name == 'block5_conv1':
    break
  layer.trainable = False
  print('Capa ' + layer.name + ' congelada...')

# Cogemos la última capa del model y le añadimos nuestro clasificador (top_model)
last = base_model.layers[-1].output #(X)
x = Flatten()(last) #(X)
x = Dense(1000, activation='relu', name='fc1')(x) #(X)
x= Dropout(0.3)(x) #(X)
x = Dense(200, activation='relu', name='fc2')(x) #(X)
x = Dense(10, activation='softmax', name='predictions')(x) #(X)
model = Model(base_model.input, x) #(X)

# Compilamos el modelo
optimizer=Adam(learning_rate=0.1)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Vamos a visualizar el modelo prestando especial atención en el número de pesos total y el número de pesos entrenables.
# ¿tiene sentido en comparación al ejemplo de transfer learning?
model.summary()

# Entrenamos el modelo
H = model.fit(trainX, trainY, validation_split=0.2, batch_size=64, epochs=20, verbose=1)

# Evaluación del modelo
print("[INFO]: Evaluando el modelo...")
predictions = model.predict(testX, batch_size=64)
# Obtener el report de clasificación
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=labelNames))

# Gráficas
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 20), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 20), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 20), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 20), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 4, 4, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 1, 1, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)
# Capa input_layer_3 congelada...
# Capa block1_conv1 congelada...
# Capa block1_conv2 congelada...
# Capa block1_pool congelada...
# Capa block2_conv1 congelada...
# Capa block2_conv2 congelada...
# Capa block2_pool congelada...
# Capa block3_conv1 congelada...
# Capa block3_conv2 congelada...
# Capa block3_conv3 congelada...
# Capa block3_pool congelada...
# Capa block4_conv1 congelada...
# Capa block4_conv2 congelada...
# Capa block4_conv3 congelada...
# Capa block4_pool congelada...
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 4, 4, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 1, 1, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 1000)           │       513,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 200)            │       200,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,429,898 (58.86 MB)
#  Trainable params: 7,794,634 (29.73 MB)
#  Non-trainable params: 7,635,264 (29.13 MB)
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.0993 - loss: 71578768.0000 - val_accuracy: 0.1022 - val_loss: 2.3096
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.1009 - loss: 2.3105 - val_accuracy: 0.1003 - val_loss: 2.3085
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.1015 - loss: 2.3105 - val_accuracy: 0.0977 - val_loss: 2.3168
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.1015 - loss: 2.3116 - val_accuracy: 0.0980 - val_loss: 2.3139
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.0972 - loss: 2.3121 - val_accuracy: 0.1003 - val_loss: 2.3074
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.1006 - loss: 2.3116 - val_accuracy: 0.0980 - val_loss: 2.3071
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.0992 - loss: 2.3127 - val_accuracy: 0.1014 - val_loss: 2.3105
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.0984 - loss: 2.3120 - val_accuracy: 0.1003 - val_loss: 2.3106
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.0988 - loss: 2.3109 - val_accuracy: 0.0980 - val_loss: 2.3160
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.1013 - loss: 2.3110 - val_accuracy: 0.0997 - val_loss: 2.3116
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.1003 - loss: 2.3112 - val_accuracy: 0.0977 - val_loss: 2.3053
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.0994 - loss: 2.3112 - val_accuracy: 0.0980 - val_loss: 2.3130
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.0992 - loss: 2.3127 - val_accuracy: 0.0997 - val_loss: 2.3134
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.0996 - loss: 2.3104 - val_accuracy: 0.1014 - val_loss: 2.3133
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.0980 - loss: 2.3114 - val_accuracy: 0.0980 - val_loss: 2.3095
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.0989 - loss: 2.3111 - val_accuracy: 0.0952 - val_loss: 2.3063
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.1005 - loss: 2.3115 - val_accuracy: 0.1016 - val_loss: 2.3102
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.1008 - loss: 2.3116 - val_accuracy: 0.0952 - val_loss: 2.3067
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.0976 - loss: 2.3115 - val_accuracy: 0.1014 - val_loss: 2.3114
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.0984 - loss: 2.3118 - val_accuracy: 0.0977 - val_loss: 2.3154
# [INFO]: Evaluando el modelo...
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step
#               precision    recall  f1-score   support
#
#        Avión       0.00      0.00      0.00      1000
#    Automóvil       0.00      0.00      0.00      1000
#       Pájaro       0.00      0.00      0.00      1000
#         Gato       0.00      0.00      0.00      1000
#       Ciervo       0.00      0.00      0.00      1000
#        Perro       0.00      0.00      0.00      1000
#         Rana       0.00      0.00      0.00      1000
#      Caballo       0.10      1.00      0.18      1000
#        Barco       0.00      0.00      0.00      1000
#       Camión       0.00      0.00      0.00      1000
#
#     accuracy                           0.10     10000
#    macro avg       0.01      0.10      0.02     10000
# weighted avg       0.01      0.10      0.02     10000
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# **EJERCICIO PROPUESTO 1:** Sacar el entrenamiento del mínimo local.

# %%
# Imports que vamos a necesitar
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.applications import VGG16, imagenet_utils
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dropout, Flatten, GlobalMaxPooling2D, Dense
from tensorflow.keras import Model
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import numpy as np
from sklearn.preprocessing import LabelBinarizer

#Cargamos el dataset CIFAR10
(trainX, trainY), (testX, testY) = cifar10.load_data()

# Normalizamos las entradas de idéntica forma a como lo hicieron para entrenar la VGG16 en imageNet
trainX = imagenet_utils.preprocess_input(trainX)
testX = imagenet_utils.preprocess_input(testX)

# Definimos dimensiones de nuestros datos de entrada y lista con las categorias de las clases
input_shape = (32, 32, 3)
labelNames = ["Avión", "Automóvil", "Pájaro", "Gato", "Ciervo", "Perro", "Rana", "Caballo", "Barco", "Camión"]

# En caso de inestabilidades numéricas pasar datos a one-hot encoding
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

# Importamos VGG16 con pesos de imagenet y sin top_model especificando tamaño de entrada de datos
base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
# Mostramos la arquitectura
base_model.summary()

# Congelamos las capas de los 4 primeros bloques convolucionales, el quinto se re-entrena
# En base_model.layers.name tenemos la información del nombre de la capa
for layer in base_model.layers:
  if layer.name == 'block5_conv3':
    break
  layer.trainable = False
  print('Capa ' + layer.name + ' congelada...')

# Cogemos la última capa del model y le añadimos nuestro clasificador (top_model)
last = base_model.layers[-1].output #(X)
x = Flatten()(last) #(X)
x = Dense(1000, activation='relu', name='fc1')(x) #(X)
x= Dropout(0.3)(x) #(X)
x = Dense(200, activation='relu', name='fc2')(x) #(X)
x = Dense(10, activation='softmax', name='predictions')(x) #(X)
model = Model(base_model.input, x) #(X)

# Compilamos el modelo
optimizer=Adam(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Vamos a visualizar el modelo prestando especial atención en el número de pesos total y el número de pesos entrenables.
# ¿tiene sentido en comparación al ejemplo de transfer learning?
model.summary()

# Entrenamos el modelo
H = model.fit(trainX, trainY, validation_split=0.2, batch_size=64, epochs=20, verbose=1)

# Evaluación del modelo
print("[INFO]: Evaluando el modelo...")
predictions = model.predict(testX, batch_size=64)
# Obtener el report de clasificación
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=labelNames))

# Gráficas
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 20), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 20), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 20), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 20), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 4, 4, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 1, 1, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)
# Capa input_layer_5 congelada...
# Capa block1_conv1 congelada...
# Capa block1_conv2 congelada...
# Capa block1_pool congelada...
# Capa block2_conv1 congelada...
# Capa block2_conv2 congelada...
# Capa block2_pool congelada...
# Capa block3_conv1 congelada...
# Capa block3_conv2 congelada...
# Capa block3_conv3 congelada...
# Capa block3_pool congelada...
# Capa block4_conv1 congelada...
# Capa block4_conv2 congelada...
# Capa block4_conv3 congelada...
# Capa block4_pool congelada...
# Capa block5_conv1 congelada...
# Capa block5_conv2 congelada...
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 4, 4, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 1, 1, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 1000)           │       513,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 200)            │       200,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,429,898 (58.86 MB)
#  Trainable params: 3,075,018 (11.73 MB)
#  Non-trainable params: 12,354,880 (47.13 MB)
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - accuracy: 0.2137 - loss: 9.3933 - val_accuracy: 0.2500 - val_loss: 1.7551
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.1248 - loss: 2.2878 - val_accuracy: 0.0952 - val_loss: 2.3037
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.1009 - loss: 2.3047 - val_accuracy: 0.1014 - val_loss: 2.3034
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.0968 - loss: 2.3037 - val_accuracy: 0.1014 - val_loss: 2.3035
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.0971 - loss: 2.3164 - val_accuracy: 0.1022 - val_loss: 2.3028
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.0993 - loss: 2.3052 - val_accuracy: 0.0980 - val_loss: 2.3033
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.0963 - loss: 2.3047 - val_accuracy: 0.1016 - val_loss: 2.3037
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.1014 - loss: 2.3074 - val_accuracy: 0.1012 - val_loss: 2.3056
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.0973 - loss: 2.3045 - val_accuracy: 0.0977 - val_loss: 2.3033
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.1016 - loss: 2.3042 - val_accuracy: 0.0977 - val_loss: 2.3028
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.0991 - loss: 2.3036 - val_accuracy: 0.0997 - val_loss: 2.3037
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.0983 - loss: 2.3040 - val_accuracy: 0.1014 - val_loss: 2.3037
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.0997 - loss: 2.3036 - val_accuracy: 0.0980 - val_loss: 2.3037
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.0984 - loss: 2.3035 - val_accuracy: 0.1025 - val_loss: 2.3031
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.0983 - loss: 2.3047 - val_accuracy: 0.1025 - val_loss: 2.3027
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.1014 - loss: 2.3034 - val_accuracy: 0.0952 - val_loss: 2.3037
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.0986 - loss: 2.3036 - val_accuracy: 0.1022 - val_loss: 2.3033
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.1008 - loss: 2.3100 - val_accuracy: 0.1016 - val_loss: 2.3031
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.0984 - loss: 2.3035 - val_accuracy: 0.1014 - val_loss: 2.3045
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.0990 - loss: 2.3059 - val_accuracy: 0.0997 - val_loss: 2.3033
# [INFO]: Evaluando el modelo...
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step
#               precision    recall  f1-score   support
#
#        Avión       0.00      0.00      0.00      1000
#    Automóvil       0.00      0.00      0.00      1000
#       Pájaro       0.00      0.00      0.00      1000
#         Gato       0.00      0.00      0.00      1000
#       Ciervo       0.10      1.00      0.18      1000
#        Perro       0.00      0.00      0.00      1000
#         Rana       0.00      0.00      0.00      1000
#      Caballo       0.00      0.00      0.00      1000
#        Barco       0.00      0.00      0.00      1000
#       Camión       0.00      0.00      0.00      1000
#
#     accuracy                           0.10     10000
#    macro avg       0.01      0.10      0.02     10000
# weighted avg       0.01      0.10      0.02     10000
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# **EJERCICIO PROPUESTO 2:** Combinar fine tuning con la técnica de data augmentation para reducir overfitting.

# %%
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15, # grados de rotacion aleatoria
    width_shift_range=0.2, # fraccion del total (1) para mover la imagen
    height_shift_range=0.2, # fraccion del total (1) para mover la imagen
    horizontal_flip=True, # girar las imagenes horizontalmente (eje vertical)
    # shear_range=0, # deslizamiento
    zoom_range=0.2, # rango de zoom
    # fill_mode='nearest', # como rellenar posibles nuevos pixeles
    # channel_shift_range=0.2 # cambios aleatorios en los canales de la imagen
    validation_split=0.2,
)

# %%
# Imports que vamos a necesitar
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.applications import VGG16, imagenet_utils
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dropout, Flatten, GlobalMaxPooling2D, Dense
from tensorflow.keras import Model
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import numpy as np
from sklearn.preprocessing import LabelBinarizer

#Cargamos el dataset CIFAR10
(trainX, trainY), (testX, testY) = cifar10.load_data()

# Normalizamos las entradas de idéntica forma a como lo hicieron para entrenar la VGG16 en imageNet
trainX = imagenet_utils.preprocess_input(trainX)
testX = imagenet_utils.preprocess_input(testX)

# Definimos dimensiones de nuestros datos de entrada y lista con las categorias de las clases
input_shape = (32, 32, 3)
labelNames = ["Avión", "Automóvil", "Pájaro", "Gato", "Ciervo", "Perro", "Rana", "Caballo", "Barco", "Camión"]

# En caso de inestabilidades numéricas pasar datos a one-hot encoding
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

# Importamos VGG16 con pesos de imagenet y sin top_model especificando tamaño de entrada de datos
base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
# Mostramos la arquitectura
base_model.summary()

# Congelamos las capas de los 4 primeros bloques convolucionales, el quinto se re-entrena
# En base_model.layers.name tenemos la información del nombre de la capa
for layer in base_model.layers:
  if layer.name == 'block5_conv3':
    break
  layer.trainable = False
  print('Capa ' + layer.name + ' congelada...')

# Cogemos la última capa del model y le añadimos nuestro clasificador (top_model)
last = base_model.layers[-1].output #(X)
x = Flatten()(last) #(X)
x = Dense(1000, activation='relu', name='fc1')(x) #(X)
x = Dropout(0.3)(x) #(X)
x = Dense(200, activation='relu', name='fc2')(x) #(X)
x = Dense(10, activation='softmax', name='predictions')(x) #(X)
model = Model(base_model.input, x) #(X)

# Compilamos el modelo
optimizer=Adam(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Vamos a visualizar el modelo prestando especial atención en el número de pesos total y el número de pesos entrenables.
# ¿tiene sentido en comparación al ejemplo de transfer learning?
model.summary()


# Entrenamiento de la red
print("[INFO]: Entrenando la red...")
H = model.fit(datagen.flow(trainX, trainY, batch_size=128, subset="training"), validation_data=datagen.flow(trainX, trainY, batch_size=32, subset="validation"),  epochs=20, verbose=1)

# Evaluación del modelo
print("[INFO]: Evaluando el modelo...")
predictions = model.predict(testX, batch_size=64)
# Obtener el report de clasificación
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=labelNames))

# Gráficas
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 20), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 20), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 20), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 20), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 4, 4, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 1, 1, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)
# Capa input_layer_6 congelada...
# Capa block1_conv1 congelada...
# Capa block1_conv2 congelada...
# Capa block1_pool congelada...
# Capa block2_conv1 congelada...
# Capa block2_conv2 congelada...
# Capa block2_pool congelada...
# Capa block3_conv1 congelada...
# Capa block3_conv2 congelada...
# Capa block3_conv3 congelada...
# Capa block3_pool congelada...
# Capa block4_conv1 congelada...
# Capa block4_conv2 congelada...
# Capa block4_conv3 congelada...
# Capa block4_pool congelada...
# Capa block5_conv1 congelada...
# Capa block5_conv2 congelada...
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 4, 4, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 2, 2, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 1, 1, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 1000)           │       513,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 200)            │       200,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,429,898 (58.86 MB)
#  Trainable params: 3,075,018 (11.73 MB)
#  Non-trainable params: 12,354,880 (47.13 MB)
# [INFO]: Entrenando la red...
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 123ms/step - accuracy: 0.1001 - loss: 20.5000 - val_accuracy: 0.0999 - val_loss: 2.3027
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 112ms/step - accuracy: 0.0974 - loss: 2.3032 - val_accuracy: 0.0974 - val_loss: 2.3030
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 113ms/step - accuracy: 0.0980 - loss: 2.3033 - val_accuracy: 0.0999 - val_loss: 2.3031
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 111ms/step - accuracy: 0.1007 - loss: 2.3033 - val_accuracy: 0.0937 - val_loss: 2.3039
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 36s 114ms/step - accuracy: 0.1005 - loss: 2.3050 - val_accuracy: 0.0999 - val_loss: 2.3032
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 34s 108ms/step - accuracy: 0.0993 - loss: 2.3034 - val_accuracy: 0.0974 - val_loss: 2.3028
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 111ms/step - accuracy: 0.0979 - loss: 2.3057 - val_accuracy: 0.1001 - val_loss: 2.3033
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 108ms/step - accuracy: 0.0979 - loss: 2.3039 - val_accuracy: 0.0937 - val_loss: 2.3035
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 110ms/step - accuracy: 0.1004 - loss: 2.3033 - val_accuracy: 0.0999 - val_loss: 2.3041
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 112ms/step - accuracy: 0.0981 - loss: 2.3034 - val_accuracy: 0.1016 - val_loss: 2.3031
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 34s 108ms/step - accuracy: 0.0979 - loss: 2.3035 - val_accuracy: 0.0937 - val_loss: 2.3036
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 37s 120ms/step - accuracy: 0.0978 - loss: 2.3036 - val_accuracy: 0.1032 - val_loss: 2.3034
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 34s 108ms/step - accuracy: 0.0998 - loss: 2.3032 - val_accuracy: 0.1016 - val_loss: 2.3032
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 38s 120ms/step - accuracy: 0.1009 - loss: 2.3032 - val_accuracy: 0.1016 - val_loss: 2.3030
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 34s 109ms/step - accuracy: 0.0985 - loss: 2.3033 - val_accuracy: 0.0981 - val_loss: 2.3037
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 38s 121ms/step - accuracy: 0.1002 - loss: 2.3032 - val_accuracy: 0.0937 - val_loss: 2.3038
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 111ms/step - accuracy: 0.1006 - loss: 2.3035 - val_accuracy: 0.1001 - val_loss: 2.3034
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 36s 116ms/step - accuracy: 0.0988 - loss: 2.3034 - val_accuracy: 0.0974 - val_loss: 2.3036
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 112ms/step - accuracy: 0.0987 - loss: 2.3032 - val_accuracy: 0.1001 - val_loss: 2.3037
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 36s 115ms/step - accuracy: 0.0996 - loss: 2.3032 - val_accuracy: 0.1001 - val_loss: 2.3038
# [INFO]: Evaluando el modelo...
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step
#               precision    recall  f1-score   support
#
#        Avión       0.00      0.00      0.00      1000
#    Automóvil       0.00      0.00      0.00      1000
#       Pájaro       0.00      0.00      0.00      1000
#         Gato       0.00      0.00      0.00      1000
#       Ciervo       0.00      0.00      0.00      1000
#        Perro       0.00      0.00      0.00      1000
#         Rana       0.00      0.00      0.00      1000
#      Caballo       0.10      1.00      0.18      1000
#        Barco       0.00      0.00      0.00      1000
#       Camión       0.00      0.00      0.00      1000
#
#     accuracy                           0.10     10000
#    macro avg       0.01      0.10      0.02     10000
# weighted avg       0.01      0.10      0.02     10000
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Comparacion entre Perceptrón, Red Neuronal Convolucional y Data Augmentation
# ## Perceptrón
# Es el modelo mas básico de una red neuronal, pues es una neurona con la capacidad de añadir pesos a sus entradas  pero que no puede realizar procesos que sean no lienales como XOR
#
# ## Red Neuronal Convolucional
# Es una red profunda que se utiliza para procesar principalemte imagenes y extraer caracteristicas de las mismas pero puede llegar a tener complicaiones por su alto coste omputacional y datos necesarios, ademas de que puede llegar a realizar el overfitting
#
# ## Data Augmentation
# Es una tecnica que aumenta de manera artificial los datos al realizar cambios en los mismos como Rotaciones, Volteos, Zoom, Ruido, Cambio de brillo, etc, y el realizar dicho proceso tiene como objetivo eliminar el overfitting y mejorar la generalización
#
# ### Tabla comparativa
#
# | Característica | Perceptrón | CNN (Red Neuronal Convolucional) | Data Augmentation |
# |--------------|-----------|----------------------------------|-------------------|
# | Tipo | Modelo simple | Modelo profundo (Deep Learning) | Técnica de preprocesamiento |
# | Memoria | Limitada | Compleja  | No tiene memoria |
# | Tipo de aprendizaje | Lineal | No lineal | No aprende nada |
# | Datos necesarios | Pocos | Muchos | Aumenta artificialmente los datos |
# | Uso en imágenes | Deficiente | Excelente | Mejora el rendimiento |
# | Computacional | Bajo | Alto | Bajo |
# | Riesgo de overfitting | Bajo | Alto | Reduce el overfitting |
# | Ejemplo de uso | Clasificación simple | Clasificación de imágenes | Rotaciones, flips, zoom, etc

# %% [markdown]
# ### Repositorio
# * https://github.com/enderliliessad-pixel/Cuaderno_Machine2.git
