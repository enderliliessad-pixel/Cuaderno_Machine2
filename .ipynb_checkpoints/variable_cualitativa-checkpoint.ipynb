# %% [markdown]
# ![jupyter](img/logo-itq.png)
#
# # Variable_cualitativa
# ## PAO26-27 - Python 01
#
# ![jupyter](img/logo-py.png)
#
# **Nombre:** *David Ruiz*
# Variable_cualitativa

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Doctorado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Doctorado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Master'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Master' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Grado' 'Doctorado' 'Master' 'Secundaria' 'Grado'
#  'Secundaria' 'Master' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Grado' 'Secundaria' 'Master' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Master' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Grado' 'Master' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Master' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Grado' 'Master' 'Secundaria' 'Master' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Master' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Doctorado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Doctorado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Doctorado' 'Secundaria' 'Grado' 'Master' 'Bachillerato' 'Master'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Master' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Master'
#  'Master' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Doctorado' 'Grado' 'Grado'
#  'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Grado' 'Grado' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Doctorado' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado'
#  'Doctorado' 'Grado' 'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Master' 'Master' 'Master' 'Master' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato' 'Master' 'Master'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Doctorado' 'Doctorado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Master'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Master'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Master'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Doctorado' 'Secundaria'
#  'Grado' 'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Doctorado' 'Secundaria' 'Master' 'Master'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = ['red', 'blue', 'orange', 'green', 'cyan']
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información 
import pandas as pd

df = pd.DataFrame({
    'nivel_estudios': nivel_estudios
})

print(df.head())
# Out:
#   nivel_estudios
# 0      Doctorado
# 1   Bachillerato
# 2   Bachillerato
# 3     Secundaria
# 4         Master

# %%
repeticiones_pd.plot(kind='bar')

plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras con pandas')
plt.show()

# %%
repeticiones_pd.plot(kind='pie', autopct='%1.2f%%')

plt.title('Diagrama de sectores con pandas')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Repositorio
# * https://github.com/enderliliessad-pixel/Cuaderno_Machine2.git
