# %% [markdown]
# ![jupyter](img/logo-itq.png)
#
# # Introducción
# ## PAO25-25 - Python 01
#
# ![jupyter](img/logo-py.png)
#
# **Nombre:** *David Ruiz*
# ## Introducción a Python
#
# ### Características Principales
